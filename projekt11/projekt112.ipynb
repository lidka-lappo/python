# %%
import pandas as pd
import numpy as np

# %%
tt = pd.read_csv('titanic_relationships.csv')
tt.head()
# Out:
#    Survived  PassengerId  Pclass       Name  \
# 0       0.0            1       3     Braund
# 1       1.0            2       1    Cumings
# 2       1.0            3       3  Heikkinen
# 3       1.0            4       1   Futrelle
# 4       0.0            5       3      Allen
#
#                                        Surname     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
tt['Name']
# Out:
# 0              Braund
# 1             Cumings
# 2           Heikkinen
# 3            Futrelle
# 4               Allen
#             ...
# 1304          Spector
# 1305    Oliva y Ocana
# 1306          Saether
# 1307             Ware
# 1308            Peter
# Name: Name, Length: 1309, dtype: object

# %%
tt[['Survived', 'Pclass','Age']]
# Out:
#       Survived  Pclass   Age
# 0          0.0       3  22.0
# 1          1.0       1  38.0
# 2          1.0       3  26.0
# 3          1.0       1  35.0
# 4          0.0       3  35.0
# ...        ...     ...   ...
# 1304       NaN       3   NaN
# 1305       NaN       1  39.0
# 1306       NaN       3  38.5
# 1307       NaN       3   NaN
# 1308       NaN       3   NaN
#
# [1309 rows x 3 columns]

# %%
tt.columns
# Out:
# Index(['Survived', 'PassengerId', 'Pclass', 'Name', 'Surname', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
tt.Age.describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
tt.loc[tt.Sex =='female']
# Out:
#       Survived  PassengerId  Pclass           Name  \
# 1          1.0            2       1        Cumings
# 2          1.0            3       3      Heikkinen
# 3          1.0            4       1       Futrelle
# 8          1.0            9       3        Johnson
# 9          1.0           10       2         Nasser
# ...        ...          ...     ...            ...
# 1300       NaN         1301       3        Peacock
# 1301       NaN         1302       3       Naughton
# 1302       NaN         1303       1        Minahan
# 1303       NaN         1304       3     Henriksson
# 1305       NaN         1306       1  Oliva y Ocana
#
#                                           Surname     Sex   Age  SibSp  Parch  \
# 1      Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                     Miss. Laina  female  26.0      0      0
# 3              Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
tt.loc[(tt.Sex =='female')&(tt.Survived == 1)]
# Out:
#      Survived  PassengerId  Pclass       Name  \
# 1         1.0            2       1    Cumings
# 2         1.0            3       3  Heikkinen
# 3         1.0            4       1   Futrelle
# 8         1.0            9       3    Johnson
# 9         1.0           10       2     Nasser
# ..        ...          ...     ...        ...
# 874       1.0          875       2    Abelson
# 875       1.0          876       3      Najib
# 879       1.0          880       1     Potter
# 880       1.0          881       2    Shelley
# 887       1.0          888       1     Graham
#
#                                          Surname     Sex   Age  SibSp  Parch  \
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 8       Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0      2
# ...

# %%
tt.loc[(tt.Sex =='female')&(tt.Survived == 1)&(tt.Pclass==1)]
# Out:
#      Survived  PassengerId  Pclass      Name  \
# 1         1.0            2       1   Cumings
# 3         1.0            4       1  Futrelle
# 11        1.0           12       1   Bonnell
# 31        1.0           32       1   Spencer
# 52        1.0           53       1    Harper
# ..        ...          ...     ...       ...
# 856       1.0          857       1      Wick
# 862       1.0          863       1     Swift
# 871       1.0          872       1  Beckwith
# 879       1.0          880       1    Potter
# 887       1.0          888       1    Graham
#
#                                            Surname     Sex   Age  SibSp  \
# 1       Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3               Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                                 Miss. Elizabeth  female  58.0      0
# 31           Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ...

# %%
tt.groupby('Pclass').agg(All_alive_in_calss = ('Survived', np.sum))
# Out:
#         All_alive_in_calss
# Pclass
# 1                    136.0
# 2                     87.0
# 3                    119.0

# %%
tt.groupby('Sex').agg(All_alive_in_calss = ('Survived', np.sum))
# Out:
#         All_alive_in_calss
# Sex
# female               233.0
# male                 109.0

# %%
tt.groupby('Pclass').agg(calss = ('Fare', np.sum))
# Out:
#              calss
# Pclass
# 1       28265.4043
# 2        5866.6374
# 3        9418.4452
